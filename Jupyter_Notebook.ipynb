# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# **Emmanuel Ofori Amanfo**
# <br> Data Analyst </br>

# %% [markdown]
# *I hold BSc Mathematics and MSc Industrial Finance and Investment. I enjoy working with numbers and I always look for courses and job opportunities that involve the use, application and interpretation of numbers. I am interested in Data Science because it gives me the required environment to follow my dream and passion.*

# %% [markdown]
# <h3>The Following Code displays today's time and date</h3>

# %%
import datetime 
message = "Today's Date and Time is " 
print (message , datetime.datetime.now() )
# Out:
# Today's Date and Time is  2022-10-04 10:46:08.621878

# %% [markdown]
# ### My Favourite Courses
# 1. Mathematics
# 2. Statistics
# 3. Probability
# 4. Calculus
# 5. Linear Algebra
# 6. Data Mining
# 7. Data Visualization
# 8. Programming
# 9. Machine Learning
# 10. Artificial Intelligence

# %% [markdown]
# ### My Recommended Data Courses
# <table>
#     <tr>
#     <th>Course Name</th>
#     <th>Provider</th>
#     <th>Platform</th>
#   </tr>
#   <tr>
#     <td><a href="https://www.coursera.org/professional-certificates/ibm-data-science" target="_blank">IBM Data Science<a/></td>
#     <td>IBM</td>
#     <td>Coursera</td>
#   </tr>
#   <tr>
#     <td> <a href="https://www.coursera.org/professional-certificates/ibm-data-analyst" target="_blank">IBM Data Analyst<a/></td>
#     <td>IBM</td>
#     <td>Coursera</td>
#   </tr>
#   <tr>
#     <td><a href="https://www.coursera.org/professional-certificates/google-data-analytics?=" target="_blank">Google Data Analytics<a/></td>
#     <td>Google</td>
#     <td>Coursera</td>
#   </tr>
#   <tr>
#     <td> <a href="https://www.coursera.org/professional-certificates/meta-database-engineer?" target="_blank"> Meta Database Engineer <a/></td>
#     <td>Meta</td>
#     <td>Coursera </td>
#   </tr>
# </table>
